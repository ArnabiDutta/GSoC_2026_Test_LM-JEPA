# %% [markdown]
# # ML4Sci GSoC 2026: Symbolic Calculations in High Energy Physics
# ### **Project 2.5: LM-JEPA for Squared Amplitude Calculation**
#
# **Submitted by:** ARNABI DUTTA
#
# This notebook documents the pipeline for predicting Quantum Electrodynamics (QED) and Quantum Chromodynamics (QCD) squared amplitudes using a Joint Embedding Predictive Architecture (LM-JEPA).
#
# Unlike standard text-based sequence-to-sequence models, this pipeline introduces three core data and representation experiments:
# 1. **Notation Topology (`--notation`):** Comparing standard `infix` mathematical representation against 1D Polish `prefix` notation to evaluate which structure reduces sequence length and improves algebraic learning.
# 2. **Index Permutation Augmentation (`--augment_multiplier`):** Exploiting the physical permutation symmetry of Feynman diagrams to dynamically expand the data distribution and prevent data starvation.
# 3. **LLM-JEPA Objective:** Following the official implementation, utilizing dual forward-passes to align continuous target representations via Cosine Similarity rather than relying entirely on string memorization.

# %%
import os
import sys
import pandas as pd
import torch
import matplotlib.pyplot as plt

sys.path.insert(0, os.path.abspath('./'))
from data.tokenizer import PhysicsAwareTokenizer
from models.llm_jepa import LLM_JEPA

# Set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Execution Device: {device}")
# Out:
# Execution Device: cuda

# %% [markdown]
# # Common Task 1.2
# ### Preprocessing & Symmetry Augmentation
#
# High-Energy Physics equations suffer from data starvation and arbitrary index naming. However, Feynman diagrams possess **Permutation Symmetry**
#
# Permutation symmetry in Feynman diagrams relates to the indistinguishability of internal vertices and lines, determining the symmetry factor that acts as a divisor to the overall amplitude. These symmetries arise from rearranging vertices or propagators without changing the diagram's topology, accounting for multiple identical Wick contractions.
# Reference- https://arxiv.org/abs/1011.4142
#
#
#
# **Splitting & Augmentation :**
# To prevent data leakage, the raw dataset is strictly split into an 80/10/10 ratio (Train/Val/Test) *before* any augmentation occurs. Once isolated, the training set is augmented using the `--augment_multiplier` flag. The preprocessing script (`scripts/01_preprocess_data.py`) extracts and protects physical kinematic variables (like $s_{12}, m_e, p_3$), and applies a seeded random shuffle to generic indices (e.g., `%gam_115`). This artificially expands the dataset by a factor of 15x, creating a robust training distribution keeping mathematical exactness.

# %%
# Execute the preprocessing and augmentation pipeline
# !python scripts/01_preprocess_data.py --raw_data_dir "/media/kavinder/hdd/Arnabi/SYMBA-Test Data" --augment_multiplier 15 --output_dir ./data/processed
# Out:
# Parsing QCD-2-to-2-diag-TreeLevel-0.txt: 46it [00:00, 291.21it/s]
# Parsing QCD-2-to-2-diag-TreeLevel-1.txt: 42it [00:00, 299.39it/s]
# Parsing QCD-2-to-2-diag-TreeLevel-2.txt: 38it [00:00, 275.22it/s]
# Parsing QCD-2-to-2-diag-TreeLevel-3.txt: 34it [00:00, 276.95it/s]
# Parsing QCD-2-to-2-diag-TreeLevel-4.txt: 30it [00:00, 260.33it/s]
# Parsing QCD-2-to-2-diag-TreeLevel-5.txt: 26it [00:00, 235.19it/s]
# Parsing QCD-2-to-2-diag-TreeLevel-6.txt: 18it [00:00, 235.46it/s]
# Parsing QED-2-to-2-diag-TreeLevel-0.txt: 54it [00:00, 791.67it/s]
# Parsing QED-2-to-2-diag-TreeLevel-1.txt: 50it [00:00, 891.04it/s]
# Parsing QED-2-to-2-diag-TreeLevel-2.txt: 46it [00:00, 781.04it/s]
# Parsing QED-2-to-2-diag-TreeLevel-3.txt: 42it [00:00, 760.14it/s]
# Parsing QED-2-to-2-diag-TreeLevel-4.txt: 38it [00:00, 718.28it/s]
# Parsing QED-2-to-2-diag-TreeLevel-5.txt: 34it [00:00, 708.08it/s]
# Parsing QED-2-to-2-diag-TreeLevel-6.txt: 30it [00:00, 711.15it/s]
# Parsing QED-2-to-2-diag-TreeLevel-7.txt: 26it [00:00, 660.47it/s]
# Parsing QED-2-to-2-diag-TreeLevel-8.txt: 22it [00:00, 683.08it/s]
# Parsing QED-2-to-2-diag-TreeLevel-9.txt: 18it [00:00, 748.29it/s]
#
# Total Unique Interactions Created: 8907
#
# Processing QED data (5397 samples)...
# Saved QED: Train=4317, Val=539, Test=541
#
# Processing QCD data (3510 samples)...
# Saved QCD: Train=2808, Val=351, Test=351

# %% [markdown]
# ### Tokenizer
#
# Standard NLP tokenizers (like BPE or WordPiece) shatter mathematical tensors into meaningless sub-word fragments. To preserve the physics, this pipeline utilizes a custom regex lexer engineered to swallow subscripts, arguments, and superscripts whole, treating complex kinematic strings as single vocabulary tokens.
#
# Raw equations undergo a rigorous standardization pass (e.g., mapping `**` to `^`, complex conjugations to `^CONJ`, and domain variables like `s_12` to `MANDELSTAM_12`).
#
# **The Notation Toggle (`--notation`):**
# When generating the vocabulary (`scripts/02_build_vocab.py`) and processing the data, we experiment with two modes:
# * `--notation infix`: The standard human-readable mathematical format.
# * `--notation prefix`: The tokens are processed through the Shunting-Yard algorithm to generate Polish Prefix notation, evaluating if 1D operator-first hierarchy improves the model's structural learning.

# %%
# !python3 scripts/02_build_vocab.py --physics_model QCD
# Out:
# Loading data from /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/data/processed/QCD_train.csv...
# Verified: Loaded 2808 training samplfPes!
# Processing amplitude vocab: 100%|█████████| 2808/2808 [00:00<00:00, 4525.99it/s]
# Processing squared amplitude vocab: 100%|█| 2808/2808 [00:00<00:00, 4654.85it/s]
# Shared vocab built in 1.23s, unique tokens: 2684
# Tokenizer and Vocab saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/data/processed for QCD
# Total QCD Vocabulary Size: 2690

# %%
# !python3 scripts/02_build_vocab.py --physics_model QED
# Out:
# Loading data from /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/data/processed/QED_train.csv...
# Verified: Loaded 4317 training samplfPes!
# Processing amplitude vocab: 100%|████████| 4317/4317 [00:00<00:00, 13973.26it/s]
# Processing squared amplitude vocab: 100%|█| 4317/4317 [00:00<00:00, 19476.85it/s
# Shared vocab built in 0.53s, unique tokens: 289
# Tokenizer and Vocab saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/data/processed for QED
# Total QED Vocabulary Size: 295

# %% [markdown]
# ### DataLoader & Masking
# To implement the LM-JEPA objective, the model must learn deep, continuous representations without being exposed to the gt.
#
# In `data/dataset.py`, we construct a additive causal mask matrix initialized to $-\infty$. We punch out specific topological triangles to allow the Amplitude to see itself, and the Squared Amplitude to see itself, but strictly forbid cross-view attention during the JEPA forward pass.

# %% [markdown]
# # Specific Task 2.5
#
# ### LLM-JEPA Architecture
#
# The model processes the data through two simultaneous forward passes as mentioned in the paper:
# 1. **The Generative Pass:** Using standard causal masking, the model predicts the next token, minimizing Cross-Entropy ($L_{CE}$).
# 2. **The JEPA Pass:** Using the blinded topological mask, the model extracts the final hidden state of the Amplitude ($h_A$) and the Squared Amplitude ($h_{A^2}$). We apply $L_2$ normalization and compute the Cosine Similarity to align the continuous manifolds.
#
# $$L_{total} = L_{CE} + \lambda_{JEPA} \left( 1 - \cos(h_A, h_{A^2}) \right)$$
#
# `models/llm_jepa.py`
# ```python
# text_rep = F.normalize(hidden_states_jepa[i, t_end_idx, :], p=2, dim=0)
# code_rep = F.normalize(hidden_states_jepa[i, c_end_idx, :], p=2, dim=0)
#
# cos_sim = F.cosine_similarity(text_rep.unsqueeze(0), code_rep.unsqueeze(0))
# jepa_loss += (1.0 - cos_sim.squeeze())

# %% [markdown]
# The script below initiates the distributed training loop via Weights & Biases, utilizing mixed-precision (`torch.autocast`) and Cosine Annealing.
#
# *Note: Training on the full augmented dataset takes several hours. For the convenience, this command is commented out. We provide the pre-trained weights for instant evaluation.*

# %%
# OPTIONAL: To train the model from scratch, uncomment the line below.
# !python scripts/03_train.py --physics_model QCD --mode jepa

# %% [markdown]
# ### Evaluation
# Because symbolic math is commutative, standard token accuracy heavily penalizes structurally valid but reordered equations. We evaluate the models using 4 criteria:
# 1. **Sequence Accuracy:** Strict exact string match.
# 2. **Token Accuracy:** Positional token-by-token alignment.
# 3. **Structural Match (Levenshtein):** Measures edit distance to identify syntactically valid but shifted mathematical trees.
# 4. **Algebraic Match (SymPy):** Generated outputs are parsed through a SymPy solver (`sympy.simplify(pred - gt) == 0`) to explicitly verify mathematical equivalence.
#
# **Prefix Reversal:** SymPy requires standard mathematical formatting. To evaluate models trained on the `--notation prefix` toggle, the inference script utilizes a reverse Shunting-Yard parser using a stack-based algorithm to reconstruct human-readable equations before feeding them to the SymPy solver. A strict 2-second `signal.alarm` timeout prevents the CPU from hanging on hallucinated, invalid topologies.
#
# Below, we download the pre-trained weights, instantiate the JEPA model, and run the evaluation script.

# %%
import os

# Create checkpoint directory
# os.makedirs("logs/jepa/checkpoints/QCD", exist_ok=True)
# ckpt_path = "logs/jepa/checkpoints/QCD/best_model.pt"

# Download the pre-trained weights
# if not os.path.exists(ckpt_path):
#     print("Downloading pre-trained LLM-JEPA weights")
#     # gdown.download('LINK TO BE UPLOADED', ckpt_path, quiet=False)
#     print("Weights downloaded successfully!")

# Run the lightning-fast evaluation script
# !python ./inference/evaluate.py --physics_model QED --mode jepa --wt_path ./logs/jepa/checkpoints/QED/best_model_QED_jepa_prefix_mult1.pt --notation prefix
# Out:
# Evaluation for QED on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QED/best_model_QED_jepa_prefix_mult1.pt
# Loaded checkpoint from epoch 75 | val_loss=0.363335
#
# Evaluating 36 samples
# Inference: 100%|████████████████████████████████| 36/36 [00:02<00:00, 13.52it/s]
#
# QED EVALUATION METRICS (JEPA)
# Total Samples:       36
# 1. Sequence Acc:     0.00% (0/36)
# 2. Token Accuracy:   35.19%
# 3. Algebraic Match:  88.89% (32/36)
# 4. Structural (Lev): 67.22%
# 5. Inference Speed:  1290.20 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : 1/9*i*e^2*gamma_{+%\sigma_980,%eta_587,%eps_277}*gamma_{%\sigma_980,%gam_499,%del_385}*s_{k_318,%eps_277}(p_1)_u*s_{l_318,%eta_587}(p_2)_v^(*)*tt_{j_320,%del_385}(p_4)_v*tt_{i_320,%gam_499}(p_3)_u^(*)/(m_s^2 + s_12 + 1/2*reg_prop)
# GT   (SqAmp) : div 1 mul 81 mul E_CHARGE^4 mul add mul 16 mul m_s^2 m_tt^2 add mul 8 mul m_tt^2 MANDELSTAM_12 add mul 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul 8 mul MANDELSTAM_13 MANDELSTAM_24 mul 8 mul m_s^2 MANDELSTAM_34 pow add m_s^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2
# PRED (SqAmp) : div 1 mul 81 mul E_CHARGE^4 mul add mul 16 mul m_b^2 m_u^2 add mul 8 mul 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul 8 mul MANDELSTAM_13 MANDELSTAM_24 mul 8 mul 8 mul 8 mul 8 mul MANDELSTAM_12 MANDELSTAM_34 pow add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2
# Matches      : Seq=False | TokenAcc=58.3% | Alg=True
#
# --- Sample 2 ---
# AMP  (Input) : -1/9*i*e^2*(p_3_%\tau_5376*gamma_{%\tau_5378,%gam_2049,%del_1361}*A_{j_1767,+%\tau_5376}(p_4)^(*)*A_{l_1765,+%\tau_5378}(p_2)*b_{k_1765,%del_1361}(p_1)_u*b_{i_1767,%gam_2049}(p_3)_u^(*) + 1/2*p_4_%\lambda_4806*gamma_{+%\lambda_4806,%gam_2081,%gam_2082}*gamma_{%\tau_5376,%gam_2052,%gam_2081}*gamma_{%\tau_5378,%gam_2082,%del_1363}*A_{j_1767,+%\tau_5376}(p_4)^(*)*A_{l_1765,+%\tau_5378}(p_2)*b_{k_1765,%del_1363}(p_1)_u*b_{i_1767,%gam_2052}(p_3)_u^(*))/(s_12 + 1/2*reg_prop)
# GT   (SqAmp) : add div 2 mul 81 mul E_CHARGE^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2 div neg 4 mul 81 mul I_UNIT mul E_CHARGE^2 div add mul I_UNIT mul E_CHARGE^2 mul m_b^2 div add m_b^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_12 div 1 mul 2 REG_PROP div neg 1 mul 2 mul I_UNIT mul E_CHARGE^2 mul m_b^2 div add MANDELSTAM_14 mul neg 2 MANDELSTAM_34 add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP
# PRED (SqAmp) : add div 2 mul 81 mul 81 mul E_CHARGE^4 mul MANDELSTAM_34 pow add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2 div neg 4 mul 81 mul 81 mul 81 mul I_UNIT mul E_CHARGE^2 div add mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul E_CHARGE^2 mul m_tt^2 div add MANDELSTAM_14 mul 2 MANDELSTAM_34 add MANDELSTAM_14 mul 2 MANDELSTAM_34 add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP
# Matches      : Seq=False | TokenAcc=20.1% | Alg=True
#
# --- Sample 3 ---
# AMP  (Input) : -1/18*i*e^2*gamma_{+%\tau_14399,%gam_5152,%gam_5153}*gamma_{%\tau_14399,%gam_5154,%del_4357}*b_{j_5593,%gam_5154}(p_4)_u^(*)*b_{l_5591,%del_4357}(p_2)_u*d_{i_5593,%gam_5152}(p_3)_u^(*)*d_{k_5591,%gam_5153}(p_1)_u/(m_d^2 + -s_13 + 1/2*reg_prop)
# GT   (SqAmp) : div 1 mul 324 mul E_CHARGE^4 mul add mul 16 mul m_b^2 m_d^2 add mul neg 8 mul m_b^2 MANDELSTAM_13 add mul 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul m_d^2 MANDELSTAM_24 mul 8 mul MANDELSTAM_12 MANDELSTAM_34 pow add m_d^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP neg 2
# PRED (SqAmp) : div 1 mul 324 mul E_CHARGE^4 mul add mul 16 mul m_d^2 m_s^2 add mul neg 8 mul m_d^2 MANDELSTAM_13 add mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul m_d^2 MANDELSTAM_24 mul 8 mul 8 mul MANDELSTAM_12 MANDELSTAM_34 pow add m_d^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP neg 2
# Matches      : Seq=False | TokenAcc=72.5% | Alg=True
#
#
# Detailed results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QED/deep_evaluation_results_prefix.csv

# %%
# !python ./inference/evaluate.py --physics_model QED --mode jepa --wt_path ./logs/jepa/checkpoints/QED/best_model_QED_jepa_prefix_mult15.pt --augment_multiplier 15 --notation prefix
# Out:
# Evaluation for QED on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QED/best_model_QED_jepa_prefix_mult15.pt
# Loaded checkpoint from epoch 75 | val_loss=0.000755
#
# Evaluating 36 samples
# Inference: 100%|████████████████████████████████| 36/36 [00:01<00:00, 20.57it/s]
#
# QED EVALUATION METRICS (JEPA)
# Total Samples:       36
# 1. Sequence Acc:     94.44% (34/36)
# 2. Token Accuracy:   98.11%
# 3. Algebraic Match:  100.00% (36/36)
# 4. Structural (Lev): 99.82%
# 5. Inference Speed:  1496.53 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : -i*e^2*(p_1_%\nu_28037*gamma_{%\mu_27603,%eta_9617,%eps_7326}*A_{l_10695,+%\mu_27603}(p_2)*A_{j_10697,+%\nu_28037}(p_4)^(*)*mu_{i_10697,%eps_7326}(p_3)_v*mu_{k_10695,%eta_9617}(p_1)_v^(*) + -1/2*p_4_%\tau_27567*gamma_{%\mu_27603,%eta_9638,%eps_7328}*gamma_{%\nu_28037,%eta_9620,%eta_9637}*gamma_{+%\tau_27567,%eta_9637,%eta_9638}*A_{l_10695,+%\mu_27603}(p_2)*A_{j_10697,+%\nu_28037}(p_4)^(*)*mu_{i_10697,%eps_7328}(p_3)_v*mu_{k_10695,%eta_9620}(p_1)_v^(*))/(s_23 + -1/2*reg_prop)
# GT   (SqAmp) : add mul 2 mul E_CHARGE^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 mul neg 4 mul I_UNIT mul E_CHARGE^2 div add mul I_UNIT mul E_CHARGE^2 mul m_mu^2 div add m_mu^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul E_CHARGE^2 mul m_mu^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# PRED (SqAmp) : add mul 2 mul E_CHARGE^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 mul neg 4 mul I_UNIT mul E_CHARGE^2 div add mul I_UNIT mul E_CHARGE^2 mul m_mu^2 div add m_mu^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul E_CHARGE^2 mul m_mu^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
# --- Sample 2 ---
# AMP  (Input) : -i*e^2*(p_1_%\sigma_32132*gamma_{%\tau_30539,%gam_11545,%gam_11546}*A_{l_11829,+%\tau_30539}(p_2)*A_{j_11831,+%\sigma_32132}(p_4)^(*)*e_{i_11831,%gam_11546}(p_3)_v*e_{k_11829,%gam_11545}(p_1)_v^(*) + -1/2*p_4_%\tau_30541*gamma_{%\sigma_32132,%gam_11550,%gam_11598}*gamma_{%\tau_30539,%gam_11599,%gam_11551}*gamma_{+%\tau_30541,%gam_11598,%gam_11599}*A_{l_11829,+%\tau_30539}(p_2)*A_{j_11831,+%\sigma_32132}(p_4)^(*)*e_{i_11831,%gam_11551}(p_3)_v*e_{k_11829,%gam_11550}(p_1)_v^(*))/(s_23 + -1/2*reg_prop)
# GT   (SqAmp) : add mul 2 mul E_CHARGE^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 mul neg 4 mul I_UNIT mul E_CHARGE^2 div add mul I_UNIT mul E_CHARGE^2 mul m_e^2 div add m_e^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul E_CHARGE^2 mul m_e^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# PRED (SqAmp) : add mul 2 mul E_CHARGE^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 mul neg 4 mul I_UNIT mul E_CHARGE^2 div add mul I_UNIT mul E_CHARGE^2 mul m_e^2 div add m_e^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul E_CHARGE^2 mul m_e^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
# --- Sample 3 ---
# AMP  (Input) : 4/9*i*e^2*(p_3_%\sigma_22120*gamma_{%\mu_22360,%eta_8562,%eps_6152}*A_{j_8363,+%\sigma_22120}(p_4)^(*)*A_{l_8361,+%\mu_22360}(p_2)*u_{k_8361,%eta_8562}(p_1)_v^(*)*u_{i_8363,%eps_6152}(p_3)_v + 1/2*p_4_%\rho_21905*gamma_{%\mu_22360,%eta_8565,%eta_8586}*gamma_{+%\rho_21905,%eta_8586,%eta_8587}*gamma_{%\sigma_22120,%eta_8587,%eps_6154}*A_{j_8363,+%\sigma_22120}(p_4)^(*)*A_{l_8361,+%\mu_22360}(p_2)*u_{k_8361,%eta_8565}(p_1)_v^(*)*u_{i_8363,%eps_6154}(p_3)_v)/(s_12 + 1/2*reg_prop)
# GT   (SqAmp) : add div 32 mul 81 mul E_CHARGE^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2 div neg 64 mul 81 mul I_UNIT mul E_CHARGE^2 div add mul I_UNIT mul E_CHARGE^2 mul m_u^2 div add m_u^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_12 div 1 mul 2 REG_PROP div neg 1 mul 2 mul I_UNIT mul E_CHARGE^2 mul m_u^2 div add MANDELSTAM_14 mul neg 2 MANDELSTAM_34 add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP
# PRED (SqAmp) : add div 32 mul 81 mul E_CHARGE^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2 div neg 64 mul 81 mul I_UNIT mul E_CHARGE^2 div add mul I_UNIT mul E_CHARGE^2 mul m_u^2 div add m_u^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_12 div 1 mul 2 REG_PROP div neg 1 mul 2 mul I_UNIT mul E_CHARGE^2 mul m_u^2 div add MANDELSTAM_14 mul neg 2 MANDELSTAM_34 add MANDELSTAM_12 div 1 mul 2 REG_PROP add MANDELSTAM_12 div 1 mul 2 REG_PROP
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
#
# Detailed results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QED/deep_evaluation_results_prefix.csv

# %%
# !python ./inference/evaluate.py --physics_model QCD --mode jepa --wt_path ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_prefix_mult1.pt --augment_multiplier 1 --notation prefix
# Out:
# Evaluation for QCD on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_prefix_mult1.pt
# Loaded checkpoint from epoch 108 | val_loss=0.853821
#
# Evaluating 24 samples
# Inference: 100%|████████████████████████████████| 24/24 [00:10<00:00,  2.33it/s]
#
# QCD EVALUATION METRICS (JEPA)
# Total Samples:       24
# 1. Sequence Acc:     0.00% (0/24)
# 2. Token Accuracy:   9.45%
# 3. Algebraic Match:  50.00% (12/24)
# 4. Structural (Lev): 39.74%
# 5. Inference Speed:  710.58 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : 1/12*i*g^2*gamma_{+%\tau_9025,%eta_2410,%beta_1544}*gamma_{%\tau_9025,%gam_6639,%gam_6640}*(b_{k_2032,%F_1167,%eta_2410}(p_4)_u^(*)*b_{i_2028,%F_1167,%beta_1544}(p_2)_u*s_{j_2032,%G_3705,%gam_6640}(p_3)_v*s_{l_2026,%G_3705,%gam_6639}(p_1)_v^(*) + (-3)*b_{k_2032,%H_4067,%eta_2410}(p_4)_u^(*)*b_{i_2028,%G_3706,%beta_1544}(p_2)_u*s_{j_2032,%H_4067,%gam_6640}(p_3)_v*s_{l_2026,%G_3706,%gam_6639}(p_1)_v^(*))/(m_s^2 + -s_13 + 1/2*reg_prop)
# GT   (SqAmp) : add div neg 1 mul 16 mul g^4 mul add mul neg 16 mul m_b^2 m_s^2 add mul 8 mul m_b^2 MANDELSTAM_13 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul 8 mul m_s^2 MANDELSTAM_24 mul neg 8 mul MANDELSTAM_12 MANDELSTAM_34 pow add m_s^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP neg 2 div 1 mul 144 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 div add mul neg 16 mul m_b^2 m_s^2 add mul 8 mul m_b^2 MANDELSTAM_13 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul 8 mul m_s^2 MANDELSTAM_24 mul neg 8 mul MANDELSTAM_12 MANDELSTAM_34 add m_s^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP mul 32 mul I_UNIT mul g^2 div add mul m_b^2 m_s^2 add div neg 1 mul 2 mul m_b^2 MANDELSTAM_13 add div 1 mul 2 mul MANDELSTAM_14 MANDELSTAM_23 add div neg 1 mul 2 mul m_s^2 MANDELSTAM_24 div 1 mul 2 mul MANDELSTAM_12 MANDELSTAM_34 add m_s^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add m_s^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP
# PRED (SqAmp) : add div neg 1 mul g^4 mul g^4 mul g^4 mul g^4 mul add mul neg 16 mul m_b^2 m_s^2 add mul 8 mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul 8 mul 8 mul 8 mul 8 mul 8 mul 8 mul 8 mul neg 8 mul 8 mul 8 mul 8 mul neg 8 mul 8 mul 8 mul neg 8 mul 8 mul neg 8 mul m_s^2 MANDELSTAM_24 mul MANDELSTAM_12 MANDELSTAM_34 pow add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP neg 2 div 1 mul I_UNIT mul g^2 div add mul g^2 div add mul m_b^2 m_s^2 add mul neg 16 mul m_b^2 MANDELSTAM_13 add mul neg 16 mul m_b^2 MANDELSTAM_13 add mul neg 16 mul 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul 8 mul neg 8 mul 8 mul MANDELSTAM_12 MANDELSTAM_34 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 add m_s^2 MANDELSTAM_13 div 1 mul 2 REG_PROP
# Matches      : Seq=False | TokenAcc=10.0% | Alg=True
#
# --- Sample 2 ---
# AMP  (Input) : -g*(i*g*p_1_%\sigma_9480*gamma_{%\mu_13717,%eta_11651,%eta_11652}*T_C_10_{%g_8535,%D_12979,%C_10982}*T_C_10_{%h_1604,%B_4067,%D_12979}*G_{k_2474,%g_8535,+%\sigma_9480}(p_4)^(*)*G_{i_2470,%h_1604,+%\mu_13717}(p_2)*t_{j_2462,%C_10982,%eta_11652}(p_3)_v*t_{l_2456,%B_4067,%eta_11651}(p_1)_v^(*) + -i*g*p_3_%\sigma_9480*gamma_{%\mu_13717,%eta_11653,%eta_11654}*T_C_10_{%g_8536,%D_12980,%C_10982}*T_C_10_{%h_1605,%B_4067,%D_12980}*G_{k_2474,%g_8536,+%\sigma_9480}(p_4)^(*)*G_{i_2470,%h_1605,+%\mu_13717}(p_2)*t_{j_2462,%C_10982,%eta_11654}(p_3)_v*t_{l_2456,%B_4067,%eta_11653}(p_1)_v^(*) + -i*g*p_1_%\sigma_9480*gamma_{%\mu_13717,%eta_11659,%eta_11660}*T_C_10_{%g_8539,%B_4067,%D_12989}*T_C_10_{%h_1608,%D_12989,%C_10982}*G_{k_2474,%g_8539,+%\sigma_9480}(p_4)^(*)*G_{i_2470,%h_1608,+%\mu_13717}(p_2)*t_{j_2462,%C_10982,%eta_11660}(p_3)_v*t_{l_2456,%B_4067,%eta_11659}(p_1)_v^(*) + i*g*p_3_%\sigma_9480*gamma_{%\mu_13717,%eta_11661,%eta_11662}*T_C_10_{%g_8540,%B_4067,%D_12990}*T_C_10_{%h_1609,%D_12990,%C_10982}*G_{k_2474,%g_8540,+%\sigma_9480}(p_4)^(*)*G_{i_2470,%h_1609,+%\mu_13717}(p_2)*t_{j_2462,%C_10982,%eta_11662}(p_3)_v*t_{l_2456,%B_4067,%eta_11661}(p_1)_v^(*) + -1/2*i*g*p_1_%\sigma_9482*gamma_{%\mu_13717,%eta_11667,%eta_11668}*T_C_10_{%g_8543,%D_12983,%C_10982}*T_C_10_{%h_1612,%B_4067,%D_12983}*G_{k_2474,%g_8543,+%\mu_13717}(p_4)^(*)*G_{i_2470,%h_1612,+%\sigma_9482}(p_2)*t_{j_2462,%C_10982,%eta_11668}(p_3)_v*t_{l_2456,%B_4067,%eta_11667}(p_1)_v^(*) + 1/2*i*g*p_3_%\sigma_9482*gamma_{%\mu_13717,%eta_11669,%eta_11670}*T_C_10_{%g_8544,%D_12984,%C_10982}*T_C_10_{%h_1613,%B_4067,%D_12984}*G_{k_2474,%g_8544,+%\mu_13717}(p_4)^(*)*G_{i_2470,%h_1613,+%\sigma_9482}(p_2)*t_{j_2462,%C_10982,%eta_11670}(p_3)_v*t_{l_2456,%B_4067,%eta_11669}(p_1)_v^(*) + 1/2*i*g*p_1_%\sigma_9482*gamma_{%\mu_13717,%eta_11671,%eta_11672}*T_C_10_{%g_8545,%B_4067,%D_12993}*T_C_10_{%h_1614,%D_12993,%C_10982}*G_{k_2474,%g_8545,+%\mu_13717}(p_4)^(*)*G_{i_2470,%h_1614,+%\sigma_9482}(p_2)*t_{j_2462,%C_10982,%eta_11672}(p_3)_v*t_{l_2456,%B_4067,%eta_11671}(p_1)_v^(*) + -1/2*i*g*p_3_%\sigma_9482*gamma_{%\mu_13717,%eta_11673,%eta_11674}*T_C_10_{%g_8546,%B_4067,%D_12994}*T_C_10_{%h_1615,%D_12994,%C_10982}*G_{k_2474,%g_8546,+%\mu_13717}(p_4)^(*)*G_{i_2470,%h_1615,+%\sigma_9482}(p_2)*t_{j_2462,%C_10982,%eta_11674}(p_3)_v*t_{l_2456,%B_4067,%eta_11673}(p_1)_v^(*) + -1/2*i*g*p_4_%\sigma_9480*gamma_{%\mu_13717,%eta_11699,%eta_11700}*T_C_10_{%g_8551,%D_12985,%C_10982}*T_C_10_{%h_1620,%B_4067,%D_12985}*G_{k_2474,%g_8551,+%\sigma_9480}(p_4)^(*)*G_{i_2470,%h_1620,+%\mu_13717}(p_2)*t_{j_2462,%C_10982,%eta_11700}(p_3)_v*t_{l_2456,%B_4067,%eta_11699}(p_1)_v^(*) + 1/2*i*g*p_4_%\sigma_9480*gamma_{%\mu_13717,%eta_11701,%eta_11702}*T_C_10_{%g_8552,%B_4067,%D_12995}*T_C_10_{%h_1621,%D_12995,%C_10982}*G_{k_2474,%g_8552,+%\sigma_9480}(p_4)^(*)*G_{i_2470,%h_1621,+%\mu_13717}(p_2)*t_{j_2462,%C_10982,%eta_11702}(p_3)_v*t_{l_2456,%B_4067,%eta_11701}(p_1)_v^(*) + i*g*p_4_+%\mu_13717*gamma_{%\mu_13717,%eta_11703,%eta_11704}*T_C_10_{%g_8553,%D_12986,%C_10982}*T_C_10_{%h_1622,%B_4067,%D_12986}*G_{k_2474,%g_8553,%\sigma_9650}(p_4)^(*)*G_{i_2470,%h_1622,+%\sigma_9650}(p_2)*t_{j_2462,%C_10982,%eta_11704}(p_3)_v*t_{l_2456,%B_4067,%eta_11703}(p_1)_v^(*) + -i*g*p_4_+%\mu_13717*gamma_{%\mu_13717,%eta_11705,%eta_11706}*T_C_10_{%g_8554,%B_4067,%D_12996}*T_C_10_{%h_1623,%D_12996,%C_10982}*G_{k_2474,%g_8554,%\sigma_9660}(p_4)^(*)*G_{i_2470,%h_1623,+%\sigma_9660}(p_2)*t_{j_2462,%C_10982,%eta_11706}(p_3)_v*t_{l_2456,%B_4067,%eta_11705}(p_1)_v^(*) + -1/2*i*g*p_4_%\sigma_9527*gamma_{%\mu_13717,%eta_11707,%eta_11708}*T_C_10_{%g_8555,%D_12987,%C_10982}*T_C_10_{%h_1624,%B_4067,%D_12987}*G_{k_2474,%g_8555,+%\mu_13717}(p_4)^(*)*G_{i_2470,%h_1624,+%\sigma_9527}(p_2)*t_{j_2462,%C_10982,%eta_11708}(p_3)_v*t_{l_2456,%B_4067,%eta_11707}(p_1)_v^(*) + 1/2*i*g*p_4_%\sigma_9527*gamma_{%\mu_13717,%eta_11709,%eta_11710}*T_C_10_{%g_8555,%B_4067,%D_12997}*T_C_10_{%h_1624,%D_12997,%C_10982}*G_{k_2474,%g_8555,+%\mu_13717}(p_4)^(*)*G ...
# GT   (SqAmp) : add div neg 1 mul 2 mul g^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP neg 2 add div neg 1 mul 576 mul g^4 mul add mul MANDELSTAM_13 add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 add mul neg 1024 mul m_t^2 add m_t^2 div neg 1 mul 2 MANDELSTAM_13 add mul neg 1024 mul MANDELSTAM_14 MANDELSTAM_34 mul neg 224 mul m_t^2 add MANDELSTAM_14 MANDELSTAM_34 pow add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP neg 2 add div 7 mul 18 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 mul m_t^2 div add m_t^2 MANDELSTAM_13 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div 8 mul 7 mul I_UNIT mul g^2 mul MANDELSTAM_14 div MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div 16 mul 7 mul I_UNIT mul g^2 div add mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_14 div neg 1 mul 1024 mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div neg 1 mul 896 mul I_UNIT mul g^2 div add mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_14 add mul neg 1024 mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_34 mul 64 mul MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div neg 8 mul 7 mul I_UNIT mul g^2 div add mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_14 add div neg 1 mul 1024 mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_34 div 1 mul 2 mul MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add mul neg I_UNIT mul g^2 div add mul m_t^2 add m_t^2 MANDELSTAM_13 add div neg 1 mul 448 mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_14 add div 16 mul 7 mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_34 div neg 1 mul 7 mul MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP div 1 mul 896 mul I_UNIT mul g^2 div add mul MANDELSTAM_13 add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 add mul neg 1024 mul m_t^2 add m_t^2 div neg 1 mul 2 MANDELSTAM_13 mul neg 224 mul m_t^2 add MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div neg 7 mul 18 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 mul m_t^2 div add m_t^2 MANDELSTAM_13 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div neg 1 mul 7 mul I_UNIT mul g^2 mul MANDELSTAM_14 div MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div neg 1 mul 448 mul I_UNIT mul g^2 div add mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_14 mul neg 1024 mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div 1 mul 896 mul I_UNIT mul g^2 div add mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_14 add mul neg 1024 mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_34 mul 64 mul MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div 8 mul 7 mul I_UNIT mul g^2 div add mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_14 add div neg 1 mul 1024 mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_34 div 1 mul 2 mul MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add mul neg I_UNIT mul g^2 div add mul m_t^2 add m_t^2 MANDELSTAM_13 add div 16 mul 7 mul add m_t^2 div neg 1 mul 2 MANDELSTAM_13 MANDELSTAM_14 add div neg 1 mul 448 mul add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 MANDELSTAM_34 div 8 mul 7 mul MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP add div neg 1 mul 896 mul I_UNIT mul g^2 div add mul MANDELSTAM_13 add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 add mul neg 1024 mul m_t^2 add m_t^2 div neg 1 mul 2 MANDELSTAM_13 mul neg 224 mul m_t^2 add MANDELSTAM_14 MANDELSTAM_34 add m_t^2 add neg MANDELSTAM_13 div 1 mul 2 REG_PROP div 1 mul 448 mul I_UNIT mul g^2 div add mul m_t^2 add mul 128 m_t^2 mul neg 64 MANDELSTAM_13 add mul neg 1024 ...
# PRED (SqAmp) : add div neg 1 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul g^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add m_t^2 add m_t^2 add neg MANDELSTAM_13 add mul 2 REG_PROP neg MANDELSTAM_13 add div neg MANDELSTAM_13 add div neg MANDELSTAM_13 add div neg MANDELSTAM_13 add div neg MANDELSTAM_13 add div neg MANDELSTAM_13 add mul add mul add mul add mul add mul add mul add mul add mul add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 div 1 mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 div 1 mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 div 1 mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 div 1 mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 div 1 mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg MANDELSTAM_13 add mul neg
# Matches      : Seq=False | TokenAcc=7.3% | Alg=False
#
# --- Sample 3 ---
# AMP  (Input) : 1/12*i*g^2*gamma_{+%\tau_347,%gam_325,%eps_78}*gamma_{%\tau_347,%gam_326,%del_319}*(s_{j_80,%H_103,%gam_326}(p_3)_u^(*)*s_{k_80,%H_103,%del_319}(p_4)_v*u_{i_80,%C_102,%gam_325}(p_2)_v^(*)*u_{l_78,%C_102,%eps_78}(p_1)_u + (-3)*s_{j_80,%C_103,%gam_326}(p_3)_u^(*)*s_{k_80,%D_139,%del_319}(p_4)_v*u_{i_80,%D_139,%gam_325}(p_2)_v^(*)*u_{l_78,%C_103,%eps_78}(p_1)_u)/(m_u^2 + s_12 + 1/2*reg_prop)
# GT   (SqAmp) : add div neg 1 mul 16 mul g^4 mul add mul neg 16 mul m_s^2 m_u^2 add mul neg 8 mul m_s^2 MANDELSTAM_12 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul MANDELSTAM_13 MANDELSTAM_24 mul neg 8 mul m_u^2 MANDELSTAM_34 pow add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2 div 1 mul 144 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 div add mul neg 16 mul m_s^2 m_u^2 add mul neg 8 mul m_s^2 MANDELSTAM_12 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul MANDELSTAM_13 MANDELSTAM_24 mul neg 8 mul m_u^2 MANDELSTAM_34 add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP mul 32 mul I_UNIT mul g^2 div add mul m_s^2 m_u^2 add div 1 mul 2 mul m_s^2 MANDELSTAM_12 add div 1 mul 2 mul MANDELSTAM_14 MANDELSTAM_23 add div 1 mul 2 mul MANDELSTAM_13 MANDELSTAM_24 div 1 mul 2 mul m_u^2 MANDELSTAM_34 add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP
# PRED (SqAmp) : add div neg 1 mul g^4 mul g^4 mul g^4 mul g^4 mul add mul neg 16 mul neg 16 mul m_s^2 m_u^2 add mul neg 16 mul 8 mul neg 8 mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul neg 8 mul MANDELSTAM_13 MANDELSTAM_24 mul neg 8 mul neg 8 mul neg 8 mul MANDELSTAM_12 MANDELSTAM_34 pow add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 MANDELSTAM_12 div 1 mul 2 div 1 mul 2 REG_PROP neg 2 div 1 mul 16 mul 16 mul 16 mul 16 mul 16 mul 16 mul 16 mul 16 mul 16 mul 2 div 1 mul 2 div 1 mul 2 div 1 mul 2 div 1 mul 2 div 1 mul 2 div 1 mul 2 div 1 mul 2 div 1 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul 2 mul m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 add m_u^2 MANDELSTAM_12 div 1 mul 2 REG_PROP
# Matches      : Seq=False | TokenAcc=8.0% | Alg=False
#
#
# Detailed results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QCD/deep_evaluation_results_prefix.csv

# %%
# !python ./inference/evaluate.py --physics_model QCD --mode jepa --wt_path ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_prefix_mult15.pt --augment_multiplier 15 --notation prefix
# Out:
# Evaluation for QCD on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_prefix_mult15.pt
# Loaded checkpoint from epoch 137 | val_loss=0.028463
#
# Inference: 100%|████████████████████████████████| 24/24 [00:06<00:00,  3.77it/s]
#
# QCD EVALUATION METRICS (JEPA)
# Total Samples:       24
# 1. Sequence Acc:     79.17% (19/24)
# 2. Token Accuracy:   87.13%
# 3. Algebraic Match:  79.17% (19/24)
# 4. Structural (Lev): 93.58%
# 5. Inference Speed:  692.37 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : 1/12*i*g^2*gamma_{+%\tau_347,%gam_325,%eps_78}*gamma_{%\tau_347,%gam_326,%del_319}*(s_{j_80,%H_103,%gam_326}(p_3)_u^(*)*s_{k_80,%H_103,%del_319}(p_4)_v*u_{i_80,%C_102,%gam_325}(p_2)_v^(*)*u_{l_78,%C_102,%eps_78}(p_1)_u + (-3)*s_{j_80,%C_103,%gam_326}(p_3)_u^(*)*s_{k_80,%D_139,%del_319}(p_4)_v*u_{i_80,%D_139,%gam_325}(p_2)_v^(*)*u_{l_78,%C_103,%eps_78}(p_1)_u)/(m_u^2 + s_12 + 1/2*reg_prop)
# GT   (SqAmp) : add div neg 1 mul 16 mul g^4 mul add mul neg 16 mul m_s^2 m_u^2 add mul neg 8 mul m_s^2 MANDELSTAM_12 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul MANDELSTAM_13 MANDELSTAM_24 mul neg 8 mul m_u^2 MANDELSTAM_34 pow add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2 div 1 mul 144 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 div add mul neg 16 mul m_s^2 m_u^2 add mul neg 8 mul m_s^2 MANDELSTAM_12 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul MANDELSTAM_13 MANDELSTAM_24 mul neg 8 mul m_u^2 MANDELSTAM_34 add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP mul 32 mul I_UNIT mul g^2 div add mul m_s^2 m_u^2 add div 1 mul 2 mul m_s^2 MANDELSTAM_12 add div 1 mul 2 mul MANDELSTAM_14 MANDELSTAM_23 add div 1 mul 2 mul MANDELSTAM_13 MANDELSTAM_24 div 1 mul 2 mul m_u^2 MANDELSTAM_34 add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP
# PRED (SqAmp) : add div neg 1 mul 16 mul g^4 mul add mul neg 16 mul m_s^2 m_u^2 add mul neg 8 mul m_s^2 MANDELSTAM_12 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul MANDELSTAM_13 MANDELSTAM_24 mul neg 8 mul m_u^2 MANDELSTAM_34 pow add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP neg 2 div 1 mul 144 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 div add mul neg 16 mul m_s^2 m_u^2 add mul neg 8 mul m_s^2 MANDELSTAM_12 add mul neg 8 mul MANDELSTAM_14 MANDELSTAM_23 add mul neg 8 mul MANDELSTAM_13 MANDELSTAM_24 mul neg 8 mul m_u^2 MANDELSTAM_34 add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP mul 32 mul I_UNIT mul g^2 div add mul m_s^2 m_u^2 add div 1 mul 2 mul m_s^2 MANDELSTAM_12 add div 1 mul 2 mul MANDELSTAM_14 MANDELSTAM_23 add div 1 mul 2 mul MANDELSTAM_13 MANDELSTAM_24 div 1 mul 2 mul m_u^2 MANDELSTAM_34 add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP add m_u^2 add MANDELSTAM_12 div 1 mul 2 REG_PROP
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
# --- Sample 2 ---
# AMP  (Input) : -i*g^2*(p_1_%\tau_8175*gamma_{%\nu_19634,%gam_18884,%eps_12963}*T_C_10_{%e_1584,%D_17897,%F_15759}*T_C_10_{%e_1585,%E_14756,%D_17897}*G_{i_2108,%e_1584,+%\nu_19634}(p_2)*G_{k_2112,%e_1585,+%\tau_8175}(p_4)^(*)*c_{j_2092,%F_15759,%eps_12963}(p_3)_v*c_{l_2086,%E_14756,%gam_18884}(p_1)_v^(*) + -1/2*p_4_%\tau_8177*gamma_{%\nu_19634,%gam_18911,%eps_12965}*gamma_{%\tau_8175,%gam_18887,%gam_18910}*gamma_{+%\tau_8177,%gam_18910,%gam_18911}*T_C_10_{%e_1586,%D_17898,%F_15760}*T_C_10_{%e_1587,%E_14757,%D_17898}*G_{i_2108,%e_1586,+%\nu_19634}(p_2)*G_{k_2112,%e_1587,+%\tau_8175}(p_4)^(*)*c_{j_2092,%F_15760,%eps_12965}(p_3)_v*c_{l_2086,%E_14757,%gam_18887}(p_1)_v^(*))/(s_23 + -1/2*reg_prop)
# GT   (SqAmp) : add div 4 mul 9 mul g^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 div neg 8 mul 9 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 mul m_c^2 div add m_c^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul g^2 mul m_c^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# PRED (SqAmp) : add div 4 mul 9 mul g^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 div neg 8 mul 9 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 mul m_c^2 div add m_c^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul g^2 mul m_c^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
# --- Sample 3 ---
# AMP  (Input) : i*g^2*(p_1_%\tau_17522*gamma_{%\tau_17520,%gam_17923,%gam_17924}*T_C_10_{%c_1211,%G_6529,%D_11022}*T_C_10_{%c_1212,%D_11022,%H_11599}*G_{i_2912,%c_1211,+%\tau_17520}(p_2)*G_{k_2916,%c_1212,+%\tau_17522}(p_4)^(*)*s_{j_2908,%G_6529,%gam_17923}(p_3)_u^(*)*s_{l_2902,%H_11599,%gam_17924}(p_1)_u + -1/2*p_4_%\sigma_9169*gamma_{+%\sigma_9169,%gam_17980,%gam_17981}*gamma_{%\tau_17520,%gam_17928,%gam_17980}*gamma_{%\tau_17522,%gam_17981,%gam_17929}*T_C_10_{%c_1213,%G_6530,%D_11023}*T_C_10_{%c_1214,%D_11023,%H_11600}*G_{i_2912,%c_1213,+%\tau_17520}(p_2)*G_{k_2916,%c_1214,+%\tau_17522}(p_4)^(*)*s_{j_2908,%G_6530,%gam_17928}(p_3)_u^(*)*s_{l_2902,%H_11600,%gam_17929}(p_1)_u)/(s_23 + -1/2*reg_prop)
# GT   (SqAmp) : add div 4 mul 9 mul g^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 div neg 8 mul 9 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 mul m_s^2 div add m_s^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul g^2 mul m_s^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# PRED (SqAmp) : add div 4 mul 9 mul g^4 mul MANDELSTAM_14 mul MANDELSTAM_34 pow add MANDELSTAM_23 div neg 1 mul 2 REG_PROP neg 2 div neg 8 mul 9 mul I_UNIT mul g^2 div add mul I_UNIT mul g^2 mul m_s^2 div add m_s^2 div neg 1 mul 2 MANDELSTAM_13 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP div neg 1 mul 16 mul I_UNIT mul g^2 mul m_s^2 div add mul 16 MANDELSTAM_14 mul neg 8 MANDELSTAM_34 add MANDELSTAM_23 div neg 1 mul 2 REG_PROP add MANDELSTAM_23 div neg 1 mul 2 REG_PROP
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
#
# Detailed results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QCD/deep_evaluation_results_prefix.csv

# %%
# !python ./inference/evaluate.py --physics_model QED --mode jepa --wt_path ./logs/jepa/checkpoints/QED/best_model_QED_jepa_infix_mult1.pt --augment_multiplier 1 --notation infix
# Out:
# Evaluation for QED on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QED/best_model_QED_jepa_infix_mult1.pt
# Loaded checkpoint from epoch 211 | val_loss=0.069056
#
# Evaluating 36 samples
# Inference: 100%|████████████████████████████████| 36/36 [00:02<00:00, 13.01it/s]
#
# QED EVALUATION METRICS (JEPA)
# Total Samples:       36
# 1. Sequence Acc:     63.89% (23/36)
# 2. Token Accuracy:   81.94%
# 3. Algebraic Match:  63.89% (23/36)
# 4. Structural (Lev): 96.51%
# 5. Inference Speed:  1151.13 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : 4/9*i*e^2*(p_3_%\nu_21863*gamma_{%\mu_22633,%eta_9132,%eta_9133}*A_{l_8391,+%\mu_22633}(p_2)*A_{j_8393,+%\nu_21863}(p_4)^(*)*u_{i_8393,%eta_9133}(p_3)_v*u_{k_8391,%eta_9132}(p_1)_v^(*) + 1/2*p_4_%\tau_21803*gamma_{%\mu_22633,%eta_9137,%eta_9173}*gamma_{%\nu_21863,%eta_9174,%eta_9138}*gamma_{+%\tau_21803,%eta_9173,%eta_9174}*A_{l_8391,+%\mu_22633}(p_2)*A_{j_8393,+%\nu_21863}(p_4)^(*)*u_{i_8393,%eta_9138}(p_3)_v*u_{k_8391,%eta_9137}(p_1)_v^(*))/(s_12 + 1/2*reg_prop)
# GT   (SqAmp) : 32 / 81 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 64 / 81 * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_u^2 * ( m_u^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * E_CHARGE^2 * m_u^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# PRED (SqAmp) : 32 / 81 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 64 / 81 * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_u^2 * ( m_u^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * E_CHARGE^2 * m_u^2 * m_u^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# Matches      : Seq=False | TokenAcc=68.9% | Alg=False
#
# --- Sample 2 ---
# AMP  (Input) : -i*e^2*(p_1_%\sigma_32132*gamma_{%\tau_30539,%gam_11545,%gam_11546}*A_{l_11829,+%\tau_30539}(p_2)*A_{j_11831,+%\sigma_32132}(p_4)^(*)*e_{i_11831,%gam_11546}(p_3)_v*e_{k_11829,%gam_11545}(p_1)_v^(*) + -1/2*p_4_%\tau_30541*gamma_{%\sigma_32132,%gam_11550,%gam_11598}*gamma_{%\tau_30539,%gam_11599,%gam_11551}*gamma_{+%\tau_30541,%gam_11598,%gam_11599}*A_{l_11829,+%\tau_30539}(p_2)*A_{j_11831,+%\sigma_32132}(p_4)^(*)*e_{i_11831,%gam_11551}(p_3)_v*e_{k_11829,%gam_11550}(p_1)_v^(*))/(s_23 + -1/2*reg_prop)
# GT   (SqAmp) : 2 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + ( NEG 4 ) * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_e^2 * ( m_e^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) + NEG 1 / 16 * I_UNIT * E_CHARGE^2 * m_e^2 * ( 16 * MANDELSTAM_14 + ( NEG 8 ) * MANDELSTAM_34 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP )
# PRED (SqAmp) : 2 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + ( NEG 4 ) * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_e^2 * ( m_e^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) + NEG 1 / 16 * I_UNIT * E_CHARGE^2 * m_e^2 * ( 16 * MANDELSTAM_14 + ( NEG 8 ) * MANDELSTAM_34 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP )
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
# --- Sample 3 ---
# AMP  (Input) : -2/9*i*e^2*gamma_{+%\sigma_1165,%gam_674,%del_446}*gamma_{%\sigma_1165,%gam_675,%del_447}*c_{i_351,%gam_674}(p_3)_u^(*)*c_{j_351,%del_446}(p_4)_v*tt_{k_349,%del_447}(p_1)_u*tt_{l_349,%gam_675}(p_2)_v^(*)/(m_tt^2 + s_12 + 1/2*reg_prop)
# GT   (SqAmp) : 4 / 81 * E_CHARGE^4 * ( 16 * m_c^2 * m_tt^2 + 8 * m_c^2 * MANDELSTAM_12 + 8 * MANDELSTAM_14 * MANDELSTAM_23 + 8 * MANDELSTAM_13 * MANDELSTAM_24 + 8 * m_tt^2 * MANDELSTAM_34 ) * ( m_tt^2 + MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 )
# PRED (SqAmp) : 4 / 81 * E_CHARGE^4 * ( 16 * m_c^2 * m_tt^2 + 8 * m_tt^2 * MANDELSTAM_12 + 8 * MANDELSTAM_14 * MANDELSTAM_23 + 8 * MANDELSTAM_13 * MANDELSTAM_24 + 8 * m_c^2 * MANDELSTAM_34 ) * ( m_tt^2 + MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 )
# Matches      : Seq=False | TokenAcc=96.3% | Alg=False
#
#
# Detailed results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QED/deep_evaluation_results_infix.csv

# %%
# !python ./inference/evaluate.py --physics_model QED --mode jepa --wt_path ./logs/jepa/checkpoints/QED/best_model_QED_jepa_infix_mult15.pt --augment_multiplier 15 --notation infix
# Out:
# Evaluation for QED on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QED/best_model_QED_jepa_infix_mult15.pt
# Loaded checkpoint from epoch 53 | val_loss=0.001436
#
# Evaluating 36 samples
# Inference: 100%|████████████████████████████████| 36/36 [00:02<00:00, 14.81it/s]
#
# QED EVALUATION METRICS (JEPA)
# Total Samples:       36
# 1. Sequence Acc:     94.44% (34/36)  <-- Exact Match
# 2. Token Accuracy:   99.69%
# 3. Algebraic Match:  94.44% (34/36)  <-- SymPy Verified
# 4. Structural (Lev): 99.69%
# 5. Inference Speed:  1267.41 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : -4/9*i*e^2*(p_3_%\rho_8366*gamma_{%\nu_8471,%eta_2937,%alpha_2243}*A_{l_3123,+%\nu_8471}(p_2)*A_{j_3125,+%\rho_8366}(p_4)^(*)*c_{i_3125,%eta_2937}(p_3)_u^(*)*c_{k_3123,%alpha_2243}(p_1)_u + 1/2*p_4_%\nu_8473*gamma_{%\nu_8471,%eta_2958,%alpha_2245}*gamma_{+%\nu_8473,%eta_2957,%eta_2958}*gamma_{%\rho_8366,%eta_2940,%eta_2957}*A_{l_3123,+%\nu_8471}(p_2)*A_{j_3125,+%\rho_8366}(p_4)^(*)*c_{i_3125,%eta_2940}(p_3)_u^(*)*c_{k_3123,%alpha_2245}(p_1)_u)/(s_12 + 1/2*reg_prop)
# GT   (SqAmp) : 32 / 81 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 64 / 81 * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_c^2 * ( m_c^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * E_CHARGE^2 * m_c^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# PRED (SqAmp) : 32 / 81 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 64 / 81 * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_c^2 * ( m_c^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * E_CHARGE^2 * m_c^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
# --- Sample 2 ---
# AMP  (Input) : -i*e^2*(p_1_%\tau_27769*gamma_{%\lambda_28161,%eta_10538,%eta_10539}*A_{j_10757,+%\tau_27769}(p_4)^(*)*A_{l_10755,+%\lambda_28161}(p_2)*mu_{i_10757,%eta_10539}(p_3)_v*mu_{k_10755,%eta_10538}(p_1)_v^(*) + -1/2*p_4_%\lambda_28163*gamma_{%\lambda_28161,%eta_10580,%eta_10544}*gamma_{+%\lambda_28163,%eta_10579,%eta_10580}*gamma_{%\tau_27769,%eta_10543,%eta_10579}*A_{j_10757,+%\tau_27769}(p_4)^(*)*A_{l_10755,+%\lambda_28161}(p_2)*mu_{i_10757,%eta_10544}(p_3)_v*mu_{k_10755,%eta_10543}(p_1)_v^(*))/(s_23 + -1/2*reg_prop)
# GT   (SqAmp) : 2 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + ( NEG 4 ) * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_mu^2 * ( m_mu^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) + NEG 1 / 16 * I_UNIT * E_CHARGE^2 * m_mu^2 * ( 16 * MANDELSTAM_14 + ( NEG 8 ) * MANDELSTAM_34 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP )
# PRED (SqAmp) : 2 * E_CHARGE^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + ( NEG 4 ) * I_UNIT * E_CHARGE^2 * ( I_UNIT * E_CHARGE^2 * m_mu^2 * ( m_mu^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) + NEG 1 / 16 * I_UNIT * E_CHARGE^2 * m_mu^2 * ( 16 * MANDELSTAM_14 + ( NEG 8 ) * MANDELSTAM_34 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP )
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
# --- Sample 3 ---
# AMP  (Input) : -1/18*i*e^2*gamma_{+%\tau_14399,%gam_5152,%gam_5153}*gamma_{%\tau_14399,%gam_5154,%del_4357}*b_{j_5593,%gam_5154}(p_4)_u^(*)*b_{l_5591,%del_4357}(p_2)_u*d_{i_5593,%gam_5152}(p_3)_u^(*)*d_{k_5591,%gam_5153}(p_1)_u/(m_d^2 + -s_13 + 1/2*reg_prop)
# GT   (SqAmp) : 1 / 324 * E_CHARGE^4 * ( 16 * m_b^2 * m_d^2 + ( NEG 8 ) * m_b^2 * MANDELSTAM_13 + 8 * MANDELSTAM_14 * MANDELSTAM_23 + ( NEG 8 ) * m_d^2 * MANDELSTAM_24 + 8 * MANDELSTAM_12 * MANDELSTAM_34 ) * ( m_d^2 + NEG MANDELSTAM_13 + 1 / 2 * REG_PROP ) ^ ( NEG 2 )
# PRED (SqAmp) : 1 / 324 * E_CHARGE^4 * ( 16 * m_b^2 * m_d^2 + ( NEG 8 ) * m_b^2 * MANDELSTAM_13 + 8 * MANDELSTAM_14 * MANDELSTAM_23 + ( NEG 8 ) * m_d^2 * MANDELSTAM_24 + 8 * MANDELSTAM_12 * MANDELSTAM_34 ) * ( m_d^2 + NEG MANDELSTAM_13 + 1 / 2 * REG_PROP ) ^ ( NEG 2 )
# Matches      : Seq=True | TokenAcc=100.0% | Alg=True
#
#
# Detailed results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QED/deep_evaluation_results_infix.csv

# %%
# !python ./inference/evaluate.py --physics_model QCD --mode jepa --wt_path ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_infix_mult1.pt --augment_multiplier 1 --notation infix
# Out:
# Evaluation for QCD on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_infix_mult1.pt
# Loaded checkpoint from epoch 141 | val_loss=0.927944
#
# Evaluating 24 samples
# Inference: 100%|████████████████████████████████| 24/24 [00:10<00:00,  2.39it/s]
#
# QCD EVALUATION METRICS (JEPA)
# Total Samples:       24
# 1. Sequence Acc:     0.00% (0/24)
# 2. Token Accuracy:   11.20%
# 3. Algebraic Match:  0.00% (0/24)
# 4. Structural (Lev): 32.29%
# 5. Inference Speed:  686.49 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : -i*g^2*(p_2_%\rho_923*gamma_{%\nu_810,%eta_1003,%eps_446}*T_C_10_{%b_134,%D_450,%D_4866}*T_C_10_{%h_235,%D_4866,%E_526}*G_{j_196,%h_235,+%\nu_810}(p_3)^(*)*G_{k_196,%b_134,+%\rho_923}(p_4)^(*)*d_{l_194,%E_526,%eps_446}(p_1)_u*d_{i_196,%D_450,%eta_1003}(p_2)_v^(*) + -1/2*p_4_%\rho_925*gamma_{%\nu_810,%eta_1034,%eps_448}*gamma_{%\rho_923,%eta_1006,%eta_1033}*gamma_{+%\rho_925,%eta_1033,%eta_1034}*T_C_10_{%b_135,%D_451,%D_4868}*T_C_10_{%h_236,%D_4868,%E_527}*G_{j_196,%h_236,+%\nu_810}(p_3)^(*)*G_{k_196,%b_135,+%\rho_923}(p_4)^(*)*d_{l_194,%E_527,%eps_448}(p_1)_u*d_{i_196,%D_451,%eta_1006}(p_2)_v^(*))/(s_13 + -1/2*reg_prop)
# GT   (SqAmp) : 16 / 27 * g^4 * MANDELSTAM_14 * MANDELSTAM_24 * ( MANDELSTAM_13 + NEG 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + 32 / 27 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_d^2 * ( m_d^2 + 1 / 2 * MANDELSTAM_12 ) / ( MANDELSTAM_13 + NEG 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * g^2 * m_d^2 * ( MANDELSTAM_14 + 2 * MANDELSTAM_24 ) / ( MANDELSTAM_13 + NEG 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_13 + NEG 1 / 2 * REG_PROP )
# PRED (SqAmp) : 4 / 9 * g^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( NEG 2 ) ^ ( NEG 2 ) ^ ( NEG 2 ) + NEG 1 / 2 ) + NEG 1 / 2 ) + NEG 1 / 2 ) + NEG 1 / 2 ) + NEG 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 )
# Matches      : Seq=False | TokenAcc=14.6% | Alg=False
#
# --- Sample 2 ---
# AMP  (Input) : -1/4*i*g^2*gamma_{+%\rho_656,%eta_826,%eps_214}*gamma_{%\rho_656,%eta_827,%beta_137}*(b_{j_179,%C_257,%eta_827}(p_3)_u^(*)*b_{k_179,%D_205,%beta_137}(p_4)_v*t_{l_177,%C_257,%eps_214}(p_1)_u*t_{i_179,%D_205,%eta_826}(p_2)_v^(*) + -1/3*b_{j_179,%F_192,%eta_827}(p_3)_u^(*)*b_{k_179,%F_192,%beta_137}(p_4)_v*t_{l_177,%D_206,%eps_214}(p_1)_u*t_{i_179,%D_206,%eta_826}(p_2)_v^(*))/(m_t^2 + s_12 + 1/2*reg_prop)
# GT   (SqAmp) : NEG 1 / 144 * g^4 * ( ( NEG 16 ) * m_b^2 * m_t^2 + ( NEG 8 ) * m_b^2 * MANDELSTAM_12 + ( NEG 8 ) * MANDELSTAM_14 * MANDELSTAM_23 + ( NEG 8 ) * MANDELSTAM_13 * MANDELSTAM_24 + ( NEG 8 ) * m_t^2 * MANDELSTAM_34 ) * ( m_t^2 + MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + 1 / 16 * I_UNIT * g^2 * ( I_UNIT * g^2 * ( ( NEG 16 ) * m_b^2 * m_t^2 + ( NEG 8 ) * m_b^2 * MANDELSTAM_12 + ( NEG 8 ) * MANDELSTAM_14 * MANDELSTAM_23 + ( NEG 8 ) * MANDELSTAM_13 * MANDELSTAM_24 + ( NEG 8 ) * m_t^2 * MANDELSTAM_34 ) / ( m_t^2 + MANDELSTAM_12 + 1 / 2 * REG_PROP ) + 32 / 9 * I_UNIT * g^2 * ( m_b^2 * m_t^2 + 1 / 2 * m_b^2 * MANDELSTAM_12 + 1 / 2 * MANDELSTAM_14 * MANDELSTAM_23 + 1 / 2 * MANDELSTAM_13 * MANDELSTAM_24 + 1 / 2 * m_t^2 * MANDELSTAM_34 ) / ( m_t^2 + MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( m_t^2 + MANDELSTAM_12 + 1 / 2 * REG_PROP )
# PRED (SqAmp) : NEG 1 / 16 * g^4 * ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( NEG 8 ) * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * MANDELSTAM_14 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * m_t^2 * MANDELSTAM_13 * MANDELSTAM_13 * MANDELSTAM_13 * MANDELSTAM_13 * MANDELSTAM_13 * MANDELSTAM_13 * MANDELSTAM_13 * MANDELSTAM_13 + ( m_t^2 * MANDELSTAM_13 + ( m_t^2 * MANDELSTAM_13 + ( m_t^2 * MANDELSTAM_23 + ( m_t^2 * MANDELSTAM_24 + ( m_t^2 * MANDELSTAM_34 ) ^ ( NEG MANDELSTAM_13 + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 )
# Matches      : Seq=False | TokenAcc=8.4% | Alg=False
#
# --- Sample 3 ---
# AMP  (Input) : -1/2*i*g^2*(p_2_%\rho_5857*gamma_{%\rho_5855,%eta_1045,%beta_746}*gamma_{+%\rho_5857,%eta_1044,%eta_1045}*gamma_{%\sigma_8405,%eta_1013,%eta_1044}*T_C_10_{%f_294,%H_2720,%D_16875}*T_C_10_{%f_295,%D_16875,%B_5116}*G_{i_717,%f_294,+%\sigma_8405}(p_2)*G_{l_711,%f_295,+%\rho_5855}(p_1)*b_{k_701,%B_5116,%beta_746}(p_4)_v*b_{j_697,%H_2720,%eta_1013}(p_3)_u^(*) + (-2)*p_3_%\sigma_8405*gamma_{%\rho_5855,%eta_1021,%beta_749}*T_C_10_{%f_296,%H_2721,%D_16876}*T_C_10_{%f_297,%D_16876,%B_5117}*G_{i_717,%f_296,+%\sigma_8405}(p_2)*G_{l_711,%f_297,+%\rho_5855}(p_1)*b_{k_701,%B_5117,%beta_749}(p_4)_v*b_{j_697,%H_2721,%eta_1021}(p_3)_u^(*))/(s_23 + -1/2*reg_prop)
# GT   (SqAmp) : 1 / 6 * g^4 * MANDELSTAM_23 * MANDELSTAM_24 * ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 1 / 48 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_b^2 * ( 16 * MANDELSTAM_23 + 8 * MANDELSTAM_24 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) + ( NEG 16 ) * I_UNIT * g^2 * m_b^2 * ( m_b^2 + 1 / 2 * MANDELSTAM_34 ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_23 + NEG 1 / 2 * REG_PROP )
# PRED (SqAmp) : 4 / 9 * g^4 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * m_b^2 * MANDELSTAM_34 * ( MANDELSTAM_23 + NEG 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 2 ) + NEG 2 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + NEG 8 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 ) + 1 / 2 )
# Matches      : Seq=False | TokenAcc=6.1% | Alg=False
#
#
# Detailed results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QCD/deep_evaluation_results_infix.csv

# %%
# !python ./inference/evaluate.py --physics_model QCD --mode jepa --wt_path ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_infix_mult15.pt --augment_multiplier 15 --notation infix
# Out:
# Evaluation for QCD on cuda
# Loading test data, tokenizer, and vocabulary
# Loading model weights from: ./logs/jepa/checkpoints/QCD/best_model_QCD_jepa_infix_mult15.pt
# Loaded checkpoint from epoch 134 | val_loss=0.036520
#
# Evaluating 24 samples
# Inference: 100%|████████████████████████████████| 24/24 [00:05<00:00,  4.22it/s]
#
# QCD infix EVALUATION METRICS (JEPA) (15)
# Total Samples:       24
# 1. Sequence Acc:     20.83% (5/24)  <-- Exact Match
# 2. Token Accuracy:   64.74%
# 3. Algebraic Match:  20.83% (5/24)  <-- SymPy Verified
# 4. Structural (Lev): 88.21%
# 5. Inference Speed:  878.63 tokens/sec
#
# [ RANDOM SAMPLES ]
#
# --- Sample 1 ---
# AMP  (Input) : -i*g^2*(p_3_%\tau_3122*gamma_{%\rho_9166,%eta_7231,%eps_6099}*T_C_10_{%f_752,%H_4984,%D_7765}*T_C_10_{%f_753,%D_7765,%E_539}*G_{k_1028,%f_752,+%\tau_3122}(p_4)^(*)*G_{i_1024,%f_753,+%\rho_9166}(p_2)*b_{j_1024,%H_4984,%eta_7231}(p_3)_u^(*)*b_{l_1018,%E_539,%eps_6099}(p_1)_u + 1/2*p_4_%\tau_3124*gamma_{%\rho_9166,%eta_7262,%eps_6101}*gamma_{%\tau_3122,%eta_7234,%eta_7261}*gamma_{+%\tau_3124,%eta_7261,%eta_7262}*T_C_10_{%f_754,%H_4985,%D_7766}*T_C_10_{%f_755,%D_7766,%E_540}*G_{k_1028,%f_754,+%\tau_3122}(p_4)^(*)*G_{i_1024,%f_755,+%\rho_9166}(p_2)*b_{j_1024,%H_4985,%eta_7234}(p_3)_u^(*)*b_{l_1018,%E_540,%eps_6101}(p_1)_u)/(s_12 + 1/2*reg_prop)
# GT   (SqAmp) : 4 / 9 * g^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 8 / 9 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_b^2 * ( m_b^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * g^2 * m_b^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# PRED (SqAmp) : 4 / 27 * g^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 8 / 9 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_b^2 * ( m_b^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * g^2 * m_b^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# Matches      : Seq=False | TokenAcc=99.0% | Alg=False
#
# --- Sample 2 ---
# AMP  (Input) : -i*g^2*(p_3_%\nu_12202*gamma_{%\tau_5151,%gam_10608,%eps_9518}*T_C_10_{%e_861,%D_10498,%F_8363}*T_C_10_{%e_862,%E_7778,%D_10498}*G_{i_1764,%e_861,+%\tau_5151}(p_2)*G_{k_1768,%e_862,+%\nu_12202}(p_4)^(*)*c_{j_1760,%E_7778,%gam_10608}(p_3)_u^(*)*c_{l_1754,%F_8363,%eps_9518}(p_1)_u + 1/2*p_4_%\mu_5162*gamma_{+%\mu_5162,%gam_10646,%gam_10647}*gamma_{%\nu_12202,%gam_10611,%gam_10646}*gamma_{%\tau_5151,%gam_10647,%eps_9520}*T_C_10_{%e_863,%D_10499,%F_8364}*T_C_10_{%e_864,%E_7779,%D_10499}*G_{i_1764,%e_863,+%\tau_5151}(p_2)*G_{k_1768,%e_864,+%\nu_12202}(p_4)^(*)*c_{j_1760,%E_7779,%gam_10611}(p_3)_u^(*)*c_{l_1754,%F_8364,%eps_9520}(p_1)_u)/(s_12 + 1/2*reg_prop)
# GT   (SqAmp) : 4 / 9 * g^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 8 / 9 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_c^2 * ( m_c^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * g^2 * m_c^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# PRED (SqAmp) : 4 / 27 * g^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 8 / 9 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_c^2 * ( m_c^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * g^2 * m_c^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# Matches      : Seq=False | TokenAcc=99.0% | Alg=False
#
# --- Sample 3 ---
# AMP  (Input) : i*g^2*(p_3_%\rho_15841*gamma_{%\nu_12891,%eta_22308,%alpha_3543}*T_C_10_{%g_12261,%G_6830,%D_23845}*T_C_10_{%h_3155,%D_23845,%G_6831}*G_{k_3791,%h_3155,+%\rho_15841}(p_4)^(*)*G_{i_3755,%g_12261,+%\nu_12891}(p_2)*d_{j_3771,%G_6831,%alpha_3543}(p_3)_v*d_{l_3733,%G_6830,%eta_22308}(p_1)_v^(*) + 1/2*p_4_%\nu_12893*gamma_{%\nu_12891,%eta_22311,%eta_22338}*gamma_{+%\nu_12893,%eta_22338,%eta_22339}*gamma_{%\rho_15841,%eta_22339,%alpha_3545}*T_C_10_{%g_12262,%G_6832,%D_23846}*T_C_10_{%h_3156,%D_23846,%G_6833}*G_{k_3791,%h_3156,+%\rho_15841}(p_4)^(*)*G_{i_3755,%g_12262,+%\nu_12891}(p_2)*d_{j_3771,%G_6833,%alpha_3545}(p_3)_v*d_{l_3733,%G_6832,%eta_22311}(p_1)_v^(*))/(s_12 + 1/2*reg_prop)
# GT   (SqAmp) : 4 / 9 * g^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 8 / 9 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_d^2 * ( m_d^2 + NEG 1 / 2 * MANDELSTAM_13 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * g^2 * m_d^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# PRED (SqAmp) : 16 / 27 * g^4 * MANDELSTAM_14 * MANDELSTAM_34 * ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ^ ( NEG 2 ) + NEG 8 / 27 * I_UNIT * g^2 * ( I_UNIT * g^2 * m_d^2 * ( m_d^2 + 1 / 2 * MANDELSTAM_12 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) + NEG 1 / 2 * I_UNIT * g^2 * m_d^2 * ( MANDELSTAM_14 + ( NEG 2 ) * MANDELSTAM_34 ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP ) ) / ( MANDELSTAM_12 + 1 / 2 * REG_PROP )
# Matches      : Seq=False | TokenAcc=40.4% | Alg=False
#
#
# Results saved to /media/kavinder/hdd/Arnabi/symba-hep-lm-jepa/inference/jepa/QCD/evaluation_results_infix.csv
